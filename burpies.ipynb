# %%
# !pip install opencv-python mediapipe torch fiftyone
# !pip install --upgrade --force-reinstall torchvision
# !pip install --upgrade numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Duomenų surinkimas

# %% [markdown]
# Galimi duomenų šaltiniai
#
# *   COCO - Common Objects in Context
# *   Human Action Recognition and Pose Estimation Dataset (HARPE)
# *   MPII Human Pose Dataset - Max Planck Institute for Informatics

# %%
#. https://cocodataset.org/#home
#. https://docs.voxel51.com/dataset_zoo/datasets.html#coco-2017

import fiftyone as fo
import fiftyone.zoo as foz

fo.config.dataset_zoo_dir = "/content/"


# train_dataset = foz.load_zoo_dataset("coco-2017", split="train", label_types=["detections"], classes=["person"])
# train_dataset.name = "coco-2017-validation-example-train"
# train_dataset.persistent = True

# Download the COCO-2017 validation split and load it into FiftyOne
# val_dataset = foz.load_zoo_dataset("coco-2017", split="validation", label_types=["detections"], classes=["person"])
# val_dataset.name = "coco-2017-validation-example-val"
# val_dataset.persistent = True

# test_dataset = foz.load_zoo_dataset("coco-2017", split="test", label_types=["detections"], classes=["person"])
# test_dataset.name = "coco-2017-validation-example-test"
# test_dataset.persistent = True

print(f"Duomenys išsaugoti: {fo.config.dataset_zoo_dir}")
# Out:
# Duomenys išsaugoti: /content/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !echo "Kopijuojam failus iš draivo į local"
# !cp -rf /content/drive/MyDrive/coco-2017/ /content/
# !echo "Done ✅"
# Out:
# Kopijuojam failus iš draivo į local
# Done ✅
